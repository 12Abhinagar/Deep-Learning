# %%
import numpy as np
import pandas as pd

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Flatten

# %%
(X_train,y_train),(X_test,y_test) = keras.datasets.mnist.load_data()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
y_train
# Out:
# array([5, 0, 4, ..., 5, 6, 8], shape=(60000,), dtype=uint8)

# %%
import matplotlib.pyplot as plt
plt.imshow(X_train[0])

# %%
# convert pixel range from (0-255) -> (0-1)
X_train = X_train/255
X_test = X_test/255

# %%
model = Sequential()

model.add(Flatten(input_shape=(28,28)))
model.add(Dense(128,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(10,activation='softmax'))
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 104,938 (409.91 KB)
#  Trainable params: 104,938 (409.91 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,epochs=30,validation_split=0.2)
# Out:
# Epoch 1/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9160 - loss: 0.2836 - val_accuracy: 0.9580 - val_loss: 0.1435
# Epoch 2/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9637 - loss: 0.1232 - val_accuracy: 0.9673 - val_loss: 0.1054
# Epoch 3/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9741 - loss: 0.0840 - val_accuracy: 0.9712 - val_loss: 0.0914
# Epoch 4/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9805 - loss: 0.0626 - val_accuracy: 0.9702 - val_loss: 0.0976
# Epoch 5/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9847 - loss: 0.0481 - val_accuracy: 0.9715 - val_loss: 0.1038
# Epoch 6/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9868 - loss: 0.0406 - val_accuracy: 0.9731 - val_loss: 0.0956
# Epoch 7/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9895 - loss: 0.0319 - val_accuracy: 0.9736 - val_loss: 0.1001
# Epoch 8/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9903 - loss: 0.0284 - val_accuracy: 0.9744 - val_loss: 0.0979
# Epoch 9/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9927 - loss: 0.0224 - val_accuracy: 0.9744 - val_loss: 0.1147
# Epoch 10/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9931 - loss: 0.0203 - val_accuracy: 0.9737 - val_loss: 0.1052
# Epoch 11/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9939 - loss: 0.0184 - val_accuracy: 0.9707 - val_loss: 0.1209
# Epoch 12/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9949 - loss: 0.0153 - val_accuracy: 0.9724 - val_loss: 0.1229
# Epoch 13/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9947 - loss: 0.0161 - val_accuracy: 0.9745 - val_loss: 0.1232
# Epoch 14/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9950 - loss: 0.0143 - val_accuracy: 0.9723 - val_loss: 0.1470
# Epoch 15/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9960 - loss: 0.0118 - val_accuracy: 0.9755 - val_loss: 0.1219
# Epoch 16/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9966 - loss: 0.0102 - val_accuracy: 0.9746 - val_loss: 0.1400
# Epoch 17/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9962 - loss: 0.0115 - val_accuracy: 0.9731 - val_loss: 0.1436
# Epoch 18/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9963 - loss: 0.0113 - val_accuracy: 0.9735 - val_loss: 0.1499
# Epoch 19/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9970 - loss: 0.0091 - val_accuracy: 0.9756 - val_loss: 0.1323
# Epoch 20/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9973 - loss: 0.0087 - val_accuracy: 0.9700 - val_loss: 0.1764
# Epoch 21/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9973 - loss: 0.0084 - val_accuracy: 0.9748 - val_loss: 0.1561
# Epoch 22/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9964 - loss: 0.0108 - val_accuracy: 0.9766 - val_loss: 0.1465
# Epoch 23/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9978 - loss: 0.0072 - val_accuracy: 0.9736 - val_loss: 0.1668
# Epoch 24/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9966 - loss: 0.0103 - val_accuracy: 0.9767 - val_loss: 0.1493
# Epoch 25/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9974 - loss: 0.0089 - val_accuracy: 0.9754 - val_loss: 0.1547
# Epoch 26/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9981 - loss: 0.0051 - val_accuracy: 0.9761 - val_loss: 0.1474
# Epoch 27/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9969 - loss: 0.0096 - val_accuracy: 0.9743 - val_loss: 0.1733
# Epoch 28/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9977 - loss: 0.0078 - val_accuracy: 0.9724 - val_loss: 0.2013
# Epoch 29/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9974 - loss: 0.0068 - val_accuracy: 0.9746 - val_loss: 0.1860
# Epoch 30/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9977 - loss: 0.0074 - val_accuracy: 0.9753 - val_loss: 0.1828

# %%
y_prob = model.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
y_prob
# Out:
# array([[2.4143976e-13, 7.0562571e-15, 2.5006727e-14, ..., 1.0000000e+00,
#         2.1765229e-16, 3.1497902e-10],
#        [1.0705944e-16, 2.3825898e-13, 1.0000000e+00, ..., 1.5073001e-31,
#         1.0935565e-12, 4.9163713e-24],
#        [3.5227186e-12, 9.9999988e-01, 5.5103619e-08, ..., 6.3070384e-09,
#         1.3217126e-08, 3.1430004e-11],
#        ...,
#        [2.0614584e-26, 7.1497920e-22, 3.6762490e-27, ..., 2.1174008e-18,
#         1.0427535e-18, 4.0160980e-14],
#        [1.4333271e-27, 3.9801228e-24, 0.0000000e+00, ..., 1.2046385e-24,
#         9.9982321e-11, 2.3542496e-27],
#        [2.3727830e-22, 1.6157028e-24, 2.0070829e-22, ..., 7.2259030e-31,
#         1.5848796e-19, 2.3866439e-23]], shape=(10000, 10), dtype=float32)

# %%
y_pred = y_prob.argmax(axis=1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9754

# %%
history.history
# Out:
# {'accuracy': [0.9160208106040955,
#   0.9636874794960022,
#   0.9741458296775818,
#   0.9805208444595337,
#   0.984666645526886,
#   0.9867916703224182,
#   0.9894583225250244,
#   0.9902708530426025,
#   0.9927291870117188,
#   0.9931250214576721,
#   0.9939374923706055,
#   0.9948541522026062,
#   0.9947291612625122,
#   0.9950416684150696,
#   0.9959583282470703,
#   0.9965624809265137,
#   0.9962083101272583,
#   0.9962708353996277,
#   0.9969791769981384,
#   0.9972708225250244,
#   0.9972708225250244,
#   0.9963958263397217,
#   0.9978333115577698,
#   0.9966041445732117,
#   0.9973541498184204,
#   0.9981041550636292,
#   0.996874988079071,
#   0.9977083206176758,
#   0.9973958134651184,
#   0.9977291822433472],
#  'loss': [0.2836378812789917,
#   0.12315186858177185,
#   0.08396147936582565,
#   0.06259501725435257,
#   0.04806569591164589,
#   0.04063127189874649,
#   0.03190956637263298,
#   0.02843352034687996,
#   0.022408846765756607,
#   0.020291969180107117,
#   0.018403135240077972,
#   0.015330083668231964,
#   0.016120968386530876,
#   0.014319016598165035,
#   0.011759189888834953,
#   0.010234391316771507,
#   0.011529797688126564,
#   0.011327979154884815,
#   0.009116564877331257,
#   0.008667660877108574,
#   0.00839225109666586,
#   0.01075748447328806,
#   0.007180880755186081,
#   0.010290157981216908,
#   0.008947974070906639,
#   0.005110845435410738,
#   0.00957768876105547,
#   0.007836787030100822,
#   0.006800818257033825,
#   0.00735305342823267],
#  'val_accuracy': [0.9580000042915344,
#   0.9673333168029785,
#   0.9711666703224182,
#   0.9701666831970215,
#   0.9714999794960022,
#   0.9730833172798157,
#   0.9735833406448364,
#   0.9744166731834412,
#   0.9744166731834412,
#   0.9736666679382324,
#   0.9707499742507935,
#   0.9724166393280029,
#   0.9745000004768372,
#   0.9723333120346069,
#   0.9754999876022339,
#   0.9745833277702332,
#   0.9730833172798157,
#   0.9735000133514404,
#   0.9755833148956299,
#   0.9700000286102295,
#   0.9748333096504211,
#   0.9765833616256714,
#   0.9735833406448364,
#   0.9766666889190674,
#   0.9754166603088379,
#   0.9760833382606506,
#   0.9742500185966492,
#   0.9724166393280029,
#   0.9745833277702332,
#   0.9753333330154419],
#  'val_loss': [0.1435040533542633,
#   0.1053885668516159,
#   0.09139251708984375,
#   0.09760009497404099,
#   0.10377071052789688,
#   0.09557117521762848,
#   0.10014962404966354,
#   0.09792573750019073,
#   0.11471428722143173,
#   0.10520846396684647,
#   0.12086043506860733,
#   0.12289828807115555,
#   0.12320831418037415,
#   0.14703981578350067,
#   0.12193849682807922,
#   0.14004461467266083,
#   0.14361022412776947,
#   0.1499163657426834,
#   0.13226431608200073,
#   0.17637322843074799,
#   0.15611784160137177,
#   0.14649805426597595,
#   0.16676156222820282,
#   0.1493268758058548,
#   0.154738649725914,
#   0.14737339317798615,
#   0.17333342134952545,
#   0.2012786865234375,
#   0.18602026998996735,
#   0.18276798725128174]}

# %%
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.show()

# %%
plt.imshow(X_test[1000])
y_test[1000]
# Out:
# np.uint8(9)

# %%
model.predict(X_test[1000].reshape(1,28,28)).argmax(axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# array([9])
